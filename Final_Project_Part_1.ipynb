# %% [markdown]
# ### Import dependencies

# %%
import csv
import tweepy
import pywren
from dotenv import load_dotenv
import os
import time

# %% [markdown]
# ### Set up twitter API with tweepy

# %%
load_dotenv()
access_token = os.getenv('ACCESS_TOKEN')
access_token_secret = os.getenv('ACCESS_TOKEN_SECRET')
consumer_key=os.getenv('CONSUMER_KEY')
consumer_secret=os.getenv('CONSUMER_SECRET')

# %%
#from tweepy import API
auth = tweepy.OAuthHandler(consumer_key=consumer_key, 
                           consumer_secret=consumer_secret)

auth.set_access_token(access_token, access_token_secret)
api=tweepy.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# ### Filter the fields needed for network analysis
# The fields we need are user_id, user_screen_name, retweeted_user_screen_name, and retweeted_user_id. I later found out that I only need `user_screen_name` and `retweeted_user_screen_name` for network analysis, but here I used the original code. I first filtered only the tweets that contain retweet status. I then created two lists to store the nodes and edges information separately for ease to deal with PySpark Graphframe.

# %% [markdown]
# Note that in the code I used 200 as the max number of tweets to be returned by running api.search. This can easily be scaled up by changing the `max_tweets`.

# %%
#define a function that returns the nodes and edges 
def misInfoScraper(query):
    max_tweets=200
    all_status=[]
    time.sleep(0.2) # not to make process request too frequently
    for status in tweepy.Cursor(api.search, q=query,lang="en", tweet_mode='extended').items(max_tweets):
        all_status.append(status)
    #create a dictionary to store `user_id` `user_screen_name` `retweeted_user_screen_name` `retweeted_user_name`
    nodes=[]
    edges=[]
    for tweet in all_status: 
        # only scrape those that have been retweeted since we are interested in retweet networks
        if hasattr(tweet, "retweeted_status"):
            source_node = {}
            dest_node={}  
            edge={}
            edge['source']=tweet.user.screen_name
            edge['dest']=tweet.retweeted_status.user.screen_name
            source_node['id']=tweet.user.screen_name
            source_node['type']='user_name'
            dest_node['id']=tweet.retweeted_status.user.screen_name
            dest_node['type']='retweeted_user_name'
            nodes.append(source_node)
            nodes.append(dest_node)
            edges.append(edge)
    return (nodes, edges)

# %% [markdown]
# Here I included 8 queries to identify misinformation after eyeballing tweets for misinformation, but this list can easily be extended to include more queries.

# %%
#queries
query1= 'coronavirus lie'
query2='covid lie'
query3='corona lie'
query4='not 5G corona'
query5='no 5G corona'
query6='fact 5G corona'
query7='truth 5G corona'
query8='5G responsible corona'
search_query=[query1, query2,query3,query4,query5,query6,query7,query8]

# %%
# %%time
# Set up a pywren executor and map the misInfoScraper function across all queries
pwex = pywren.default_executor()
futures = pwex.map(misInfoScraper, search_query)
results=[]
for f in futures:
    results.append(f.result())
# Out:
# CPU times: user 2.05 s, sys: 396 ms, total: 2.45 s
# Wall time: 25.8 s

# %%
#check results[0] should be a tuple containing ([nodes],[edges])
results[0]
# Out:
# ([{'id': 'smaddiebird', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'PhydeauxL', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'connect2damon', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'nwokolo_leo', 'type': 'user_name'},
#   {'id': 'mazinwakamma', 'type': 'retweeted_user_name'},
#   {'id': 'AZPatriot16', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'superyayadize', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'AZLD17GOP', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Bernadettea777', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'drizzle2', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'DonaldEBain1', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'USATopGuns', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'lisareid11', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'eddie826167681', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'AnybodyGuess', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'adders281', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'DogCrusader', 'type': 'user_name'},
#   {'id': 'UNNTV1', 'type': 'retweeted_user_name'},
#   {'id': 'MWayneG', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'PaulaShellenba1', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'tiahilllife', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'dtannie', 'type': 'user_name'},
#   {'id': 'beth2_k3a', 'type': 'retweeted_user_name'},
#   {'id': 'SandySueZoo', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Leonard_Bangkok', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'mabassca', 'type': 'user_name'},
#   {'id': 'TravisGrantham', 'type': 'retweeted_user_name'},
#   {'id': 'roseanne1952', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'crafternut', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Philhaynes12', 'type': 'user_name'},
#   {'id': 'CuestionMarque', 'type': 'retweeted_user_name'},
#   {'id': 'BruceFrench1', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Carolbraziel7g1', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'PaletteStardust', 'type': 'user_name'},
#   {'id': 'KuzzatAltay', 'type': 'retweeted_user_name'},
#   {'id': 'evangie', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'mauipaws', 'type': 'user_name'},
#   {'id': 'chssc1967', 'type': 'retweeted_user_name'},
#   {'id': 'propatriots', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'hopingforachang', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'NancyBarto', 'type': 'user_name'},
#   {'id': 'TravisGrantham', 'type': 'retweeted_user_name'},
#   {'id': 'TaraLuge', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'MizzDi', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'ChargerTeacher', 'type': 'user_name'},
#   {'id': 'TravisGrantham', 'type': 'retweeted_user_name'},
#   {'id': 'Chile7171', 'type': 'user_name'},
#   {'id': 'CEVAXIN_PTY', 'type': 'retweeted_user_name'},
#   {'id': 'Shirley29465176', 'type': 'user_name'},
#   {'id': 'RealCandaceO', 'type': 'retweeted_user_name'},
#   {'id': 'LavenderLives', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': '_Sm1ttyjr', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'bhikshu2007', 'type': 'user_name'},
#   {'id': 'KuzzatAltay', 'type': 'retweeted_user_name'},
#   {'id': 'avonlady70', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Adamo55f', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'CarolBr41960083', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Tim_Poole_', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'kpclintsman', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'truax_joy', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'kelliwardaz', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'ktheshrew', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Azuri21', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'MaD2016wiFe', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'deacon_speakin', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'InAbsentia9', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'WhirledPeas9', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'YolandaSteinke', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'SickOfTheSwamp', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'LucyKnows1', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'KeussRobert', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'StephanieIngers', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Ladymacin_ride', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'RexVttr', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Cat_Kapow', 'type': 'user_name'},
#   {'id': 'UNNTV1', 'type': 'retweeted_user_name'},
#   {'id': 'BellOfAmerica', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'JohnQPublic157', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'ChrisLomauro', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'kristi4freedom', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'shannoneffects1', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'TrinityJRanch', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'GaldeShelly', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Gulfstreamdre', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Politisourced', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'LEFinch60', 'type': 'user_name'},
#   {'id': 'chere_ella', 'type': 'retweeted_user_name'},
#   {'id': 'cyndiCDG', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'rahah_ghazali', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'ChristianOrms1', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'cosmicStar55', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': '2ndGives1st', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'jCPub19', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'joan_shyam', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'ExNYmike2', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'SeaGrapeDreams', 'type': 'user_name'},
#   {'id': 'MasterOnionB', 'type': 'retweeted_user_name'},
#   {'id': 'greeks_4Trump', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'Tanyag248', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'klr_rdr', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'hooray2040', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'MrsChico724', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Boeing747S8', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'terri_grohal', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'DianneT06564576', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'jjm25713', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Dragonflybev', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'DesertAZQ', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Deech932', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'ellen_HealthyHm', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'SandersonNoreen', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'bigfoots101', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'LyonsMme', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'leesa_fl', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'dianesandifer2', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'RalphLe89722505', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'onelove1723451', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'throughthygrace', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'LoretteBarragar', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'milothekemosabe', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'seburrus', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'news_meteor', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'bails94', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': '_L1vY_', 'type': 'user_name'},
#   {'id': 'CuestionMarque', 'type': 'retweeted_user_name'},
#   {'id': 'GregBurdick6', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'stubborngal', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'ccsmu1619', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'CarolyneCathey', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'tifotter', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'LibsNoFun', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'anuradha_author', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'jarsagar', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'LYCUSRIVER', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'SJPFISH', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'sasi2824', 'type': 'user_name'},
#   {'id': 'BangkokPostNews', 'type': 'retweeted_user_name'},
#   {'id': 'superbug75', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'gurry_susan', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'ConservConstitu', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'BlueStates2020', 'type': 'user_name'},
#   {'id': 'CuestionMarque', 'type': 'retweeted_user_name'},
#   {'id': 'Philhaynes12', 'type': 'user_name'},
#   {'id': 'CuestionMarque', 'type': 'retweeted_user_name'},
#   {'id': 'ProudlyChaotic', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'MakowskiDebbe', 'type': 'user_name'},
#   {'id': 'P8R1OT', 'type': 'retweeted_user_name'},
#   {'id': 'Anners2Honduras', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'ReneeMcCone', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Gabriel4Justice', 'type': 'user_name'},
#   {'id': 'qrayjack', 'type': 'retweeted_user_name'},
#   {'id': 'beth2_k3a', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'mcb40420', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'cinnfulbakery', 'type': 'user_name'},
#   {'id': 'HTX_Groutsmith', 'type': 'retweeted_user_name'},
#   {'id': 'RedAce66517', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'CherylN70711732', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Truth_Thunder', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'sashleysutton', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'WilliamTaft17', 'type': 'user_name'},
#   {'id': 'RMConservative', 'type': 'retweeted_user_name'},
#   {'id': 'archristiansen_', 'type': 'user_name'},
#   {'id': 'RMConservative', 'type': 'retweeted_user_name'},
#   {'id': 'jlsemmel', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'StevenFlood8', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Gary30342031', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'snickermoo1', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'WaskawyW', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'borderObserver', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'LilyBlue_22', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'MignonFeldstein', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'MooseMan1956', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'LisaEtter1', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'BGHeaven', 'type': 'user_name'},
#   {'id': 'dallasnews', 'type': 'retweeted_user_name'},
#   {'id': 'Tyrwarren1', 'type': 'user_name'},
#   {'id': 'Politicians_101', 'type': 'retweeted_user_name'},
#   {'id': 'Debbideedoodah', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'Donnafreitas3', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Nick_Clamorgan', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'Mc_Murcher44', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'afifef', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'JGrenier_DZYN', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'ttocs35', 'type': 'user_name'},
#   {'id': 'MadisonSedona', 'type': 'retweeted_user_name'},
#   {'id': 'mizjac123', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'LivingstonLD22', 'type': 'user_name'},
#   {'id': 'TravisGrantham', 'type': 'retweeted_user_name'},
#   {'id': 'Deborahcox_caye', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'Sandy__McDaniel', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'AmericanPostal', 'type': 'user_name'},
#   {'id': 'fivewincs', 'type': 'retweeted_user_name'},
#   {'id': 'dennygirltwo', 'type': 'user_name'},
#   {'id': 'RepAndyBiggsAZ', 'type': 'retweeted_user_name'},
#   {'id': 'SueM21731182', 'type': 'user_name'},
#   {'id': 'TW22137888', 'type': 'retweeted_user_name'}],
#  [{'source': 'smaddiebird', 'dest': 'MadisonSedona'},
#   {'source': 'PhydeauxL', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'connect2damon', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'nwokolo_leo', 'dest': 'mazinwakamma'},
#   {'source': 'AZPatriot16', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'superyayadize', 'dest': 'MadisonSedona'},
#   {'source': 'AZLD17GOP', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Bernadettea777', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'drizzle2', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'DonaldEBain1', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'USATopGuns', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'lisareid11', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'eddie826167681', 'dest': 'MadisonSedona'},
#   {'source': 'AnybodyGuess', 'dest': 'MadisonSedona'},
#   {'source': 'adders281', 'dest': 'BangkokPostNews'},
#   {'source': 'DogCrusader', 'dest': 'UNNTV1'},
#   {'source': 'MWayneG', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'PaulaShellenba1', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'tiahilllife', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'dtannie', 'dest': 'beth2_k3a'},
#   {'source': 'SandySueZoo', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Leonard_Bangkok', 'dest': 'BangkokPostNews'},
#   {'source': 'mabassca', 'dest': 'TravisGrantham'},
#   {'source': 'roseanne1952', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'crafternut', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Philhaynes12', 'dest': 'CuestionMarque'},
#   {'source': 'BruceFrench1', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Carolbraziel7g1', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'PaletteStardust', 'dest': 'KuzzatAltay'},
#   {'source': 'evangie', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'mauipaws', 'dest': 'chssc1967'},
#   {'source': 'propatriots', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'hopingforachang', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'NancyBarto', 'dest': 'TravisGrantham'},
#   {'source': 'TaraLuge', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'MizzDi', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'ChargerTeacher', 'dest': 'TravisGrantham'},
#   {'source': 'Chile7171', 'dest': 'CEVAXIN_PTY'},
#   {'source': 'Shirley29465176', 'dest': 'RealCandaceO'},
#   {'source': 'LavenderLives', 'dest': 'RepAndyBiggsAZ'},
#   {'source': '_Sm1ttyjr', 'dest': 'MadisonSedona'},
#   {'source': 'bhikshu2007', 'dest': 'KuzzatAltay'},
#   {'source': 'avonlady70', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Adamo55f', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'CarolBr41960083', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Tim_Poole_', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'kpclintsman', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'truax_joy', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'kelliwardaz', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'ktheshrew', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Azuri21', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'MaD2016wiFe', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'deacon_speakin', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'InAbsentia9', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'WhirledPeas9', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'YolandaSteinke', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'SickOfTheSwamp', 'dest': 'MadisonSedona'},
#   {'source': 'LucyKnows1', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'KeussRobert', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'StephanieIngers', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Ladymacin_ride', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'RexVttr', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Cat_Kapow', 'dest': 'UNNTV1'},
#   {'source': 'BellOfAmerica', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'JohnQPublic157', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'ChrisLomauro', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'kristi4freedom', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'shannoneffects1', 'dest': 'MadisonSedona'},
#   {'source': 'TrinityJRanch', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'GaldeShelly', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Gulfstreamdre', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Politisourced', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'LEFinch60', 'dest': 'chere_ella'},
#   {'source': 'cyndiCDG', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'rahah_ghazali', 'dest': 'BangkokPostNews'},
#   {'source': 'ChristianOrms1', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'cosmicStar55', 'dest': 'RepAndyBiggsAZ'},
#   {'source': '2ndGives1st', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'jCPub19', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'joan_shyam', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'ExNYmike2', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'SeaGrapeDreams', 'dest': 'MasterOnionB'},
#   {'source': 'greeks_4Trump', 'dest': 'MadisonSedona'},
#   {'source': 'Tanyag248', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'klr_rdr', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'hooray2040', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'MrsChico724', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Boeing747S8', 'dest': 'BangkokPostNews'},
#   {'source': 'terri_grohal', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'DianneT06564576', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'jjm25713', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Dragonflybev', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'DesertAZQ', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Deech932', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'ellen_HealthyHm', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'SandersonNoreen', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'bigfoots101', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'LyonsMme', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'leesa_fl', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'dianesandifer2', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'RalphLe89722505', 'dest': 'MadisonSedona'},
#   {'source': 'onelove1723451', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'throughthygrace', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'RepAndyBiggsAZ', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'LoretteBarragar', 'dest': 'MadisonSedona'},
#   {'source': 'milothekemosabe', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'seburrus', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'news_meteor', 'dest': 'BangkokPostNews'},
#   {'source': 'bails94', 'dest': 'RepAndyBiggsAZ'},
#   {'source': '_L1vY_', 'dest': 'CuestionMarque'},
#   {'source': 'GregBurdick6', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'stubborngal', 'dest': 'BangkokPostNews'},
#   {'source': 'ccsmu1619', 'dest': 'BangkokPostNews'},
#   {'source': 'CarolyneCathey', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'tifotter', 'dest': 'BangkokPostNews'},
#   {'source': 'LibsNoFun', 'dest': 'MadisonSedona'},
#   {'source': 'anuradha_author', 'dest': 'BangkokPostNews'},
#   {'source': 'jarsagar', 'dest': 'BangkokPostNews'},
#   {'source': 'LYCUSRIVER', 'dest': 'BangkokPostNews'},
#   {'source': 'SJPFISH', 'dest': 'MadisonSedona'},
#   {'source': 'sasi2824', 'dest': 'BangkokPostNews'},
#   {'source': 'superbug75', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'gurry_susan', 'dest': 'MadisonSedona'},
#   {'source': 'ConservConstitu', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'BlueStates2020', 'dest': 'CuestionMarque'},
#   {'source': 'Philhaynes12', 'dest': 'CuestionMarque'},
#   {'source': 'ProudlyChaotic', 'dest': 'MadisonSedona'},
#   {'source': 'MakowskiDebbe', 'dest': 'P8R1OT'},
#   {'source': 'Anners2Honduras', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'ReneeMcCone', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Gabriel4Justice', 'dest': 'qrayjack'},
#   {'source': 'beth2_k3a', 'dest': 'MadisonSedona'},
#   {'source': 'mcb40420', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'cinnfulbakery', 'dest': 'HTX_Groutsmith'},
#   {'source': 'RedAce66517', 'dest': 'MadisonSedona'},
#   {'source': 'CherylN70711732', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Truth_Thunder', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'sashleysutton', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'WilliamTaft17', 'dest': 'RMConservative'},
#   {'source': 'archristiansen_', 'dest': 'RMConservative'},
#   {'source': 'jlsemmel', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'StevenFlood8', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Gary30342031', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'snickermoo1', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'WaskawyW', 'dest': 'MadisonSedona'},
#   {'source': 'borderObserver', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'LilyBlue_22', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'MignonFeldstein', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'MooseMan1956', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'LisaEtter1', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'BGHeaven', 'dest': 'dallasnews'},
#   {'source': 'Tyrwarren1', 'dest': 'Politicians_101'},
#   {'source': 'Debbideedoodah', 'dest': 'MadisonSedona'},
#   {'source': 'Donnafreitas3', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Nick_Clamorgan', 'dest': 'MadisonSedona'},
#   {'source': 'Mc_Murcher44', 'dest': 'MadisonSedona'},
#   {'source': 'afifef', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'JGrenier_DZYN', 'dest': 'MadisonSedona'},
#   {'source': 'ttocs35', 'dest': 'MadisonSedona'},
#   {'source': 'mizjac123', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'LivingstonLD22', 'dest': 'TravisGrantham'},
#   {'source': 'Deborahcox_caye', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'Sandy__McDaniel', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'AmericanPostal', 'dest': 'fivewincs'},
#   {'source': 'dennygirltwo', 'dest': 'RepAndyBiggsAZ'},
#   {'source': 'SueM21731182', 'dest': 'TW22137888'}])

# %%
#check the results 
len(results)
# Out:
# 8

# %%
# combine results into two lists 
all_nodes = []
all_edges=[]
for i in range(0,8):
    all_nodes.extend(results[i][0])
    all_edges.extend(results[i][1])

# %%
all_nodes[0]
# Out:
# {'id': 'smaddiebird', 'type': 'user_name'}

# %%
all_nodes[0].keys()
# Out:
# dict_keys(['id', 'type'])

# %%
len(all_nodes) #lengh of all_nodes = 2*len(all_edges)
# Out:
# 1438

# %%
# write all_nodes into local csv
nodestoCSV=all_nodes
keys=nodestoCSV[0].keys()
with open('tweet_nodes_2.csv','w') as output_nodes:
    dict_writer= csv.DictWriter(output_nodes, keys)
    dict_writer.writeheader()
    dict_writer.writerows(nodestoCSV)

# %%
all_edges[0].keys()
# Out:
# dict_keys(['source', 'dest'])

# %%
#check length
len(all_edges)
# Out:
# 719

# %%
# write all_edges into csv
edgestoCSV=all_edges
keys2=edgestoCSV[0].keys()
with open('tweet_edges_2.csv','w') as output_edges:
    dict_writer= csv.DictWriter(output_edges, keys2)
    dict_writer.writeheader()
    dict_writer.writerows(edgestoCSV)

# %% [markdown]
# ### Upload CSV files to S3

# %%
import boto3
session = boto3.Session()
# create boto3 s3 client
s3=boto3.client('s3', 
                 region_name='us-east-1')

# %%
# create s3 bucket (no need to run since this bucket has already been created previously)
#bucket = s3.create_bucket(Bucket='finalproject2020')

# %%
bucket_response=s3.list_buckets()

# %%
# check existing buckets
bucket_response
# Out:
# {'ResponseMetadata': {'RequestId': '0E2B6ECB8105CA12',
#   'HostId': 'lvQ9e7AORqakKiuCXKLru9dpcBDs7X3neN+S5IDq9WKx6Tue9efU/pw7IzhoN2ZcRQkW0hbnvsw=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'lvQ9e7AORqakKiuCXKLru9dpcBDs7X3neN+S5IDq9WKx6Tue9efU/pw7IzhoN2ZcRQkW0hbnvsw=',
#    'x-amz-request-id': '0E2B6ECB8105CA12',
#    'date': 'Sun, 14 Jun 2020 00:01:08 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'aws-emr-resources-436654078546-us-east-1',
#    'CreationDate': datetime.datetime(2020, 5, 25, 15, 11, 28, tzinfo=tzutc())},
#   {'Name': 'aws-logs-436654078546-us-east-1',
#    'CreationDate': datetime.datetime(2020, 5, 16, 1, 33, 32, tzinfo=tzutc())},
#   {'Name': 'finalproject2020',
#    'CreationDate': datetime.datetime(2020, 6, 10, 19, 3, 16, tzinfo=tzutc())},
#   {'Name': 'mrjob-8f80937eb31450f1',
#    'CreationDate': datetime.datetime(2020, 5, 16, 2, 4, 31, tzinfo=tzutc())},
#   {'Name': 'root-pywren-94',
#    'CreationDate': datetime.datetime(2020, 5, 10, 3, 30, 12, tzinfo=tzutc())},
#   {'Name': 'tianyi-pywren-53',
#    'CreationDate': datetime.datetime(2020, 5, 10, 3, 41, 8, tzinfo=tzutc())},
#   {'Name': 'tianyi-pywren-75',
#    'CreationDate': datetime.datetime(2020, 5, 9, 18, 47, 57, tzinfo=tzutc())}],
#  'Owner': {'DisplayName': 'awslabsc0w685268t1585499615',
#   'ID': '0bcd65ab89937d91504f5fe6e6cb508384e7b219df1c48ac8f05016aea236c0d'}}

# %%
# upload our files and make them publicly available
s3.upload_file(Bucket='finalproject2020',Filename='tweet_nodes_2.csv',Key='tweet_nodes_2.csv',
              ExtraArgs={'ACL':'public-read'})
s3.upload_file(Bucket='finalproject2020',Filename='tweet_edges_2.csv',Key='tweet_edges_2.csv',
              ExtraArgs={'ACL':'public-read'})
